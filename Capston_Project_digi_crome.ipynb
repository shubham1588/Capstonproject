# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-4e37015b-1481-4f1f-8691-7e0533e2522b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e37015b-1481-4f1f-8691-7e0533e2522b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Property_data - Copy.csv")

# %%
df
# Out:
#       PropertyID  PropertyClass PropertyZone  PropertyFrontage  PropertySize  \
# 0              1             60           RL              65.0          8450
# 1              2             20           RL              80.0          9600
# 2              3             60           RL              68.0         11250
# 3              4             70           RL              60.0          9550
# 4              5             60           RL              84.0         14260
# ...          ...            ...          ...               ...           ...
# 1455        1456             60           RL              62.0          7917
# 1456        1457             20           RL              85.0         13175
# 1457        1458             70           RL              66.0          9042
# 1458        1459             20           RL              68.0          9717
# 1459        1460             20           RL              75.0          9937
#
# ...

# %%
from sklearn.model_selection import train_test_split
train,test = train_test_split(df, test_size=0.30, random_state=0)
train.to_csv('train.csv',index=False)
test.to_csv('test.csv',index=False)

# %%
train.to_csv(index=False)
# Out:
# 'PropertyID,PropertyClass,PropertyZone,PropertyFrontage,PropertySize,Street,Alley,PropertyShape,Elevation,Amenities,Orientation,Grade,Neighborhood,Condition1,Condition2,BldgType,PropertyStyle,OverallQual,OverallCond,YearBuilt,YearRemodAdd,RoofStyle,RoofMatl,Roof1Material,Roof2Material,ExteriorCladdingType,ExteriorCladdingArea,ExterQual,ExterCond,PropertyFooting,BsmntFinish,BsmntMaintenance,BsmntVisibility,BsmntFinRat1,BsmntFinSty1,BsmntFinQual1,BsmtFinSF2,BsmtUnfSF,BsmntSqFtage,Heating,HeatingEfficiency,CentralAir,Electrical,1stFlrSF,2ndFlrSF,LowQualFinSF,GrLivArea,BsmtFullBath,BsmtHalfBath,Bath1,Bath2,BedroomUpLev,KitchenUpLev,KitchenQual,CntRmsUpLev,Functional,CntFireplaces,QualFireplace,BasementType,BasementYrBlt,BasementFinish,BasementCars,BasementSqFootage,BasementQual,BasementCond,PavedDrive,WoodDeckSF,OpenPorchSF,EnclosedPorch,3SsnPorch,ScreenPorch,PoolArea,PoolQC,BoundaryFeatures,AddFeatures,AddVal,SaleMon,SaleYr,SaleType,SaleCondn,PropPrice\n65,60,RL,,9375,Pave,,Reg,Lvl,AllP
# ...

# %%
test.to_csv(index=False)
# Out:
# 'PropertyID,PropertyClass,PropertyZone,PropertyFrontage,PropertySize,Street,Alley,PropertyShape,Elevation,Amenities,Orientation,Grade,Neighborhood,Condition1,Condition2,BldgType,PropertyStyle,OverallQual,OverallCond,YearBuilt,YearRemodAdd,RoofStyle,RoofMatl,Roof1Material,Roof2Material,ExteriorCladdingType,ExteriorCladdingArea,ExterQual,ExterCond,PropertyFooting,BsmntFinish,BsmntMaintenance,BsmntVisibility,BsmntFinRat1,BsmntFinSty1,BsmntFinQual1,BsmtFinSF2,BsmtUnfSF,BsmntSqFtage,Heating,HeatingEfficiency,CentralAir,Electrical,1stFlrSF,2ndFlrSF,LowQualFinSF,GrLivArea,BsmtFullBath,BsmtHalfBath,Bath1,Bath2,BedroomUpLev,KitchenUpLev,KitchenQual,CntRmsUpLev,Functional,CntFireplaces,QualFireplace,BasementType,BasementYrBlt,BasementFinish,BasementCars,BasementSqFootage,BasementQual,BasementCond,PavedDrive,WoodDeckSF,OpenPorchSF,EnclosedPorch,3SsnPorch,ScreenPorch,PoolArea,PoolQC,BoundaryFeatures,AddFeatures,AddVal,SaleMon,SaleYr,SaleType,SaleCondn,PropPrice\n530,20,RL,,32668,Pave,,IR1,Lvl,Al
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PropertyID            1460 non-null   int64
#  1   PropertyClass         1460 non-null   int64
#  2   PropertyZone          1460 non-null   object
#  3   PropertyFrontage      1201 non-null   float64
#  4   PropertySize          1460 non-null   int64
#  5   Street                1460 non-null   object
#  6   Alley                 91 non-null     object
#  7   PropertyShape         1460 non-null   object
#  8   Elevation             1460 non-null   object
#  9   Amenities             1460 non-null   object
#  10  Orientation           1460 non-null   object
#  11  Grade                 1460 non-null   object
#  12  Neighborhood          1460 non-null   object
#  13  Condition1            1460 non-null   object
#  14  Condition2            1460 non-null   object
# ...

# %%
df.isnull().sum().sum()
# Out:
# 6965

# %%
df.isnull().sum()
# Out:
# PropertyID            0
# PropertyClass         0
# PropertyZone          0
# PropertyFrontage    259
# PropertySize          0
#                    ...
# SaleMon               0
# SaleYr                0
# SaleType              0
# SaleCondn             0
# PropPrice             0
# Length: 81, dtype: int64

# %%
df_1=df.fillna(method="pad")
df_2=df_1.fillna(method="bfill")

# %%
df_2.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder

# %%
plt.figure(figsize=[8,5])
plt.scatter("SaleYr","PropPrice",data=df_2)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot("PropPrice",data=df_2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bc866ad8700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7bc866ad8c40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7bc866ad8460>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bc866ad9180>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bc866ad9450>],
#  'means': []}

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df_2, x="BldgType", y="PropPrice")
# Out:
# <Axes: xlabel='BldgType', ylabel='PropPrice'>

# %%
df_2.shape
# Out:
# (1460, 81)

# %%
df_2.iloc[:,[1,3,4,17,18,19,20,45,46,49,50,51,54,56,58,61,62,66,67,68,69,70,71,75,76,77,80]].quantile(0.75)
# Out:
# <ipython-input-22-57a135d46a00>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_2.iloc[:,[1,3,4,17,18,19,20,45,46,49,50,51,54,56,58,61,62,66,67,68,69,70,71,75,76,77,80]].quantile(0.75)
# PropertyClass            70.00
# PropertyFrontage         80.00
# PropertySize          11601.50
# OverallQual               7.00
# OverallCond               6.00
# YearBuilt              2000.00
# YearRemodAdd           2004.00
# LowQualFinSF              0.00
# GrLivArea              1776.75
# Bath1                     2.00
# Bath2                     1.00
# BedroomUpLev              3.00
# CntRmsUpLev               7.00
# CntFireplaces             1.00
# BasementCars              2.00
# BasementSqFootage       576.00
# WoodDeckSF              168.00
# OpenPorchSF              68.00
# EnclosedPorch             0.00
# ...

# %%
df_corr=df_2.iloc[:,[1,3,4,17,18,19,20,45,46,49,50,51,54,56,58,61,62,66,67,68,69,70,71,75,76,77,80]]

# %%
df_corr.head()
# Out:
#    PropertyClass  PropertyFrontage  PropertySize  OverallQual  OverallCond  \
# 0             60              65.0          8450            7            5
# 1             20              80.0          9600            6            8
# 2             60              68.0         11250            7            5
# 3             70              60.0          9550            7            5
# 4             60              84.0         14260            8            5
#
#    YearBuilt  YearRemodAdd  LowQualFinSF  GrLivArea  Bath1  ...  WoodDeckSF  \
# 0       2003          2003             0       1710      2  ...           0
# 1       1976          1976             0       1262      2  ...         298
# 2       2001          2002             0       1786      2  ...           0
# 3       1915          1970             0       1717      1  ...           0
# 4       2000          2000             0       2198      2  ...         192
#
# ...

# %%
df_corr.corr().round(2)
# Out:
# <ipython-input-25-2780f63c1815>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr.corr().round(2)
#                    PropertyClass  PropertyFrontage  PropertySize  OverallQual  \
# PropertyClass               1.00             -0.34         -0.14         0.03
# PropertyFrontage           -0.34              1.00          0.27         0.22
# PropertySize               -0.14              0.27          1.00         0.11
# OverallQual                 0.03              0.22          0.11         1.00
# OverallCond                -0.06             -0.06         -0.01        -0.09
# YearBuilt                   0.03              0.11          0.01         0.57
# YearRemodAdd                0.04              0.07          0.01         0.55
# ...

# %%
sns.heatmap(df_corr.corr().round(2),annot=True,vmax=1)
plt.figure(figsize=(12,10))
plt.show()
# Out:
# <ipython-input-26-269970330046>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_corr.corr().round(2),annot=True,vmax=1)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
Label_encoder=preprocessing.LabelEncoder()

# %%
df_2["PropertyID"].unique()
# Out:
# array([   1,    2,    3, ..., 1458, 1459, 1460])

# %%
feature_lable=df_2["Street_2"]=Label_encoder.fit_transform(df_2["Street"])
feature_lable=df_2["Grade_2"]=Label_encoder.fit_transform(df_2["Grade"])
feature_lable=df_2["Grade_2"]=Label_encoder.fit_transform(df_2["Grade"])
feature_lable=df_2["Neighborhood_2"]=Label_encoder.fit_transform(df_2["Neighborhood"])
feature_lable=df_2["Condition2_2"]=Label_encoder.fit_transform(df_2["Condition2"])
feature_lable=df_2["ExteriorCladdingType_2"]=Label_encoder.fit_transform(df_2["ExteriorCladdingType"])
feature_lable=df_2["BsmntFinish_2"]=Label_encoder.fit_transform(df_2["BsmntFinish"])
feature_lable=df_2["BsmntFinRat1_2"]=Label_encoder.fit_transform(df_2["BsmntFinRat1"])
feature_lable=df_2["BsmntFinQual1_2"]=Label_encoder.fit_transform(df_2["BsmntFinQual1"])
feature_lable=df_2["CentralAir_2"]=Label_encoder.fit_transform(df_2["CentralAir"])
feature_lable=df_2["SaleCondn_2"]=Label_encoder.fit_transform(df_2["SaleCondn"])

# %%
print(feature_lable)
# Out:
# [4 4 4 ... 4 4 4]

# %%
df_2.head()
# Out:
#    PropertyID  PropertyClass PropertyZone  PropertyFrontage  PropertySize  \
# 0           1             60           RL              65.0          8450
# 1           2             20           RL              80.0          9600
# 2           3             60           RL              68.0         11250
# 3           4             70           RL              60.0          9550
# 4           5             60           RL              84.0         14260
#
#   Street Alley PropertyShape Elevation Amenities  ... Street_2 Grade_2  \
# 0   Pave  Grvl           Reg       Lvl    AllPub  ...        1       0
# 1   Pave  Grvl           Reg       Lvl    AllPub  ...        1       0
# 2   Pave  Grvl           IR1       Lvl    AllPub  ...        1       0
# 3   Pave  Grvl           IR1       Lvl    AllPub  ...        1       0
# 4   Pave  Grvl           IR1       Lvl    AllPub  ...        1       0
#
#   Neighborhood_2 Condition2_2 ExteriorCladdingType_2 BsmntFinish_2  \
# ...

# %%
df_2.describe().round()
# Out:
#        PropertyID  PropertyClass  PropertyFrontage  PropertySize  OverallQual  \
# count      1460.0         1460.0            1460.0        1460.0       1460.0
# mean        730.0           57.0              70.0       10517.0          6.0
# std         422.0           42.0              24.0        9981.0          1.0
# min           1.0           20.0              21.0        1300.0          1.0
# 25%         366.0           20.0              59.0        7554.0          5.0
# 50%         730.0           50.0              70.0        9478.0          6.0
# 75%        1095.0           70.0              80.0       11602.0          7.0
# max        1460.0          190.0             313.0      215245.0         10.0
#
#        OverallCond  YearBuilt  YearRemodAdd  ExteriorCladdingArea  \
# count       1460.0     1460.0        1460.0                1460.0
# mean           6.0     1971.0        1985.0                 103.0
# std            1.0       30.0          21.0                 181.0
# ...

# %%
df_2.dtypes
# Out:
# PropertyID            int64
# PropertyClass         int64
# PropertyZone         object
# PropertyFrontage    float64
# PropertySize          int64
#                      ...
# BsmntFinish_2         int64
# BsmntFinRat1_2        int64
# BsmntFinQual1_2       int64
# CentralAir_2          int64
# SaleCondn_2           int64
# Length: 91, dtype: object

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 91 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PropertyID              1460 non-null   int64
#  1   PropertyClass           1460 non-null   int64
#  2   PropertyZone            1460 non-null   object
#  3   PropertyFrontage        1460 non-null   float64
#  4   PropertySize            1460 non-null   int64
#  5   Street                  1460 non-null   object
#  6   Alley                   1460 non-null   object
#  7   PropertyShape           1460 non-null   object
#  8   Elevation               1460 non-null   object
#  9   Amenities               1460 non-null   object
#  10  Orientation             1460 non-null   object
#  11  Grade                   1460 non-null   object
#  12  Neighborhood            1460 non-null   object
#  13  Condition1              1460 non-null   object
# ...

# %% [markdown]
# ## Liner Regration

# %%
## Select X & Y variables

x=df_2.iloc[:,[3,17,18,19,26,34,38,43,44,46,47,48,49,50,51,52,54,62,75,77,81,82,83,84,85,86,87,88,89,90]]
y=df_2.iloc[:,[80]]

# %%
x.head(2)
# Out:
#    PropertyFrontage  OverallQual  OverallCond  YearBuilt  \
# 0              65.0            7            5       2003
# 1              80.0            6            8       1976
#
#    ExteriorCladdingArea  BsmntFinSty1  BsmntSqFtage  1stFlrSF  2ndFlrSF  \
# 0                 196.0           706           856       856       854
# 1                   0.0           978          1262      1262         0
#
#    GrLivArea  ...  Street_2  Grade_2  Neighborhood_2  Condition2_2  \
# 0       1710  ...         1        0               5             2
# 1       1262  ...         1        0              24             2
#
#    ExteriorCladdingType_2  BsmntFinish_2  BsmntFinRat1_2  BsmntFinQual1_2  \
# 0                       1              2               2                5
# 1                       2              2               0                5
#
#    CentralAir_2  SaleCondn_2
# 0             1            4
# 1             1            4
#
# [2 rows x 30 columns]

# %%
y.head(2)
# Out:
#    PropPrice
# 0     208500
# 1     181500

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.shape
# Out:
# (1168, 30)

# %%
x_test.shape
# Out:
# (292, 30)

# %%
y_train.shape
# Out:
# (1168, 1)

# %%
y_test.shape
# Out:
# (292, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.8693049923186615

# %%
lr.coef_
# Out:
# array([[ 2.11864416e+01,  1.54997847e+04,  6.30948798e+03,
#          3.16179679e+02,  3.74162845e+01,  4.45546173e+00,
#          1.23303866e+01,  6.49402686e+01,  5.64891005e+01,
#         -1.80229254e+01,  9.89448052e+03,  4.98337077e+03,
#          2.85401519e+03,  1.78181544e+02, -6.21854860e+03,
#         -2.39450115e+04,  6.22154714e+03,  2.44550454e+01,
#          2.25052465e-01, -5.86379711e+02,  2.45604037e+04,
#          1.62284849e+04,  4.37267039e+02, -8.14280507e+03,
#          4.81757648e+03, -1.26119450e+04, -1.10016778e+03,
#         -3.88354416e+02, -2.40763329e+03,  1.98499665e+03]])

# %%
lr.predict(x_train)
# Out:
# array([[184392.54970477],
#        [140844.22257581],
#        [151119.73439442],
#        ...,
#        [133935.491194  ],
#        [380393.308566  ],
#        [126817.38765571]])

# %%
plt.plot(lr.predict(x_train))

# %%
y_Predict=lr.predict(x_test)

# %%
y_Predict
# Out:
# array([[235422.3411786 ],
#        [189042.14322452],
#        [293932.86720462],
#        [220963.55793862],
#        [226436.27358784],
#        [200196.23588658],
#        [216425.16997856],
#        [198179.93387331],
#        [125804.4327408 ],
#        [341770.66391002],
#        [233166.41702086],
#        [224976.50670243],
#        [145234.06803583],
#        [148477.01548271],
#        [ 71250.65607397],
#        [205816.75557994],
#        [257661.24171077],
#        [283090.22675264],
#        [192374.79356572],
#        [301470.54180317],
#        [345660.77077573],
#        [200182.01985299],
#        [191546.80929093],
#        [230199.53427555],
#        [398138.07445447],
#        [241774.69704928],
#        [178708.42350024],
#        [266728.35730407],
#        [214360.9709365 ],
#        [386076.76292366],
#        [309750.16449696],
#        [197504.08852595],
#        [253766.10765746],
#        [130925.00409318],
#        [201938.40114837],
# ...

# %%
plt.scatter(y_test,y_Predict)

# %%
# Decision Tree & Clasificatio,

from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
from sklearn.metrics import accuracy_score

# %%
import inspect

print(inspect.signature(clf.fit))
# Out:
# (self, X, y, sample_weight=None, check_input=True)

# %%
print(type(x_train))
print(type(y_train))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_clf_predict=clf.predict(x_test)

# %%
y_clf_predict
# Out:
# array([375000, 178000, 164000, 199900, 202500, 258000, 224900, 187000,
#        107000, 320000, 175000, 202500, 106000, 140000, 135000, 250000,
#        239000, 271000, 122500, 222500, 335000, 176000, 167000, 275500,
#        361919, 328900, 149900, 315000, 313000, 426000, 280000, 194500,
#        250000, 102000, 183500, 226700, 127000, 412500, 426000, 385000,
#        175500, 160000, 131500,  86000, 103200, 197900, 105900, 136500,
#        105000, 139000, 157000, 110500, 232000, 160000, 127000, 325000,
#         91000, 302000, 275000, 124500, 175000, 158000, 337500, 110500,
#        312500, 144000, 230000, 109500, 129900,  72500, 155835, 115000,
#         34900, 155000, 139000, 182000, 190000, 339750, 129900, 240000,
#        325000, 127000, 220000, 237000, 144000, 198900, 177000, 277000,
#        183900, 166000, 158000, 170000, 170000, 187000, 217000, 218000,
#        125500, 171000, 109900, 190000, 102000,  82000, 175000, 136500,
# ...

# %%
accuracy_score(y_test,y_clf_predict)
# Out:
# 0.00684931506849315

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-128-e322f5823f43> in <cell line: 1>()
# ----> 1 plot_tree(clf)
#       2 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     177     """
#     178
# --> 179     check_is_fitted(decision_tree)
#     180
#     181     exporter = _MPLTreeExporter(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1388
#    1389     if not fitted:
# -> 1390         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1391
#    1392
#
# ...

# %% [markdown]
# # MAE | MSE | R2S

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
print("MAE",mean_absolute_error(y_test,y_Predict))
# Out:
# MAE 20261.44143599748

# %%
print ("MSE",mean_squared_error(y_test,y_Predict))
# Out:
# MSE 865497019.6092237

# %%
print ("RMSE",np.sqrt(mean_squared_error(y_test,y_Predict)))
# Out:
# RMSE 29419.33071314206

# %%
print("R2S",r2_score(y_test,y_Predict))
# Out:
# R2S 0.8693049923186615

# %%
# select top value of the eatch feature for pridict final value of mobile
from joblib import dump, load
dump(lr,"Final_price.joblib")
from sklearn.tree import DecisionTreeRegressor

# %%
property_price_predict=([[65,7,5,2003,196,706,856,856,854,1710,1,0,2,1,3,1,8,548,0,2008,1,0,5,2,1,2,2,5,1,4]])

# %%
lr.predict(property_price_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[223226.39639061]])
